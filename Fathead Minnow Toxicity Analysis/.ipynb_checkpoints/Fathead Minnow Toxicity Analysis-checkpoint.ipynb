# %% [markdown]
# ## Introduction

# %% [markdown]
# Fathead minnow (*Pimephales promelas*) is a species of freshwater fish from the Cyprinid family and can often be found in North American waters. Since fathead minnow is tolerant of harsh aquatic environments, it is often used to analyze various chemicals' and toxins' effects on aquatic organisms.
#
# A research conducted by M. Cassotti et al. ([DOI: 10.1080/1062936X.2015.1018938](https://www.tandfonline.com/doi/full/10.1080/1062936X.2015.1018938?scroll=top&needAccess=true)), published on *SAR and QSAR in Environmental Research*, derived six moleculer descriptors that are used to predict the concentration of $LC_{50}$, an acute toxin, in fathead minnow. The dataset collected consists of 908 instances, and 726 instances were used to train the model in the research.
#
# In the following, the correlation between the six molecular descriptors and toxicity ($LC_{50}$) is analyzed. In particular, an Support Vector Regression (SVR) model will be developed to predict the toxicity level in fathead minnow, given the concentration of the six molecular descriptors, using Python Scikit-learn and Tensorflow with Keras.

# %% [markdown]
# ## Data Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Read data from the CSV file. Note that the dataset is obtained from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/QSAR+fish+toxicity#).

# %%
df = pd.read_csv('qsar_fish_toxicity.csv')

# %%
df.info()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 1 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   3.26;0.829;1.676;0;1;1.453;3.770  907 non-null    object
# dtypes: object(1)
# memory usage: 7.2+ KB
#       3.26;0.829;1.676;0;1;1.453;3.770
# 902  2.801;0.728;2.226;0;2;0.736;3.109
# 903  3.652;0.872;0.867;2;3;3.983;4.040
# 904  3.763;0.916;0.878;0;6;2.918;4.818
# 905  2.831;1.393;1.077;0;1;0.906;5.317
# 906  4.057;1.032;1.183;1;3;4.754;8.201

# %% [markdown]
# It is shown that the data must be parsed and columns must be manually created.

# %%
df2 = pd.DataFrame({"3.26;0.829;1.676;0;1;1.453;3.770":['3.26;0.829;1.676;0;1;1.453;3.770']}) 
df = pd.concat([df, df2], ignore_index=True)
df.tail()
# Out:
#       3.26;0.829;1.676;0;1;1.453;3.770
# 903  3.652;0.872;0.867;2;3;3.983;4.040
# 904  3.763;0.916;0.878;0;6;2.918;4.818
# 905  2.831;1.393;1.077;0;1;0.906;5.317
# 906  4.057;1.032;1.183;1;3;4.754;8.201
# 907   3.26;0.829;1.676;0;1;1.453;3.770

# %%
df.columns = ['Chemicals']
df['Chemicals'].iloc[0].split(";")
df['CIC0'] = df['Chemicals'].apply(lambda x: float(x.split(";")[0]))
df['SM1_Dz(Z)'] = df['Chemicals'].apply(lambda x: float(x.split(";")[1]))
df['GATS1i'] = df['Chemicals'].apply(lambda x: float(x.split(";")[2]))
df['NdsCH'] = df['Chemicals'].apply(lambda x: float(x.split(";")[3]))
df['NdssC'] = df['Chemicals'].apply(lambda x: float(x.split(";")[4]))
df['MLOGP'] = df['Chemicals'].apply(lambda x: float(x.split(";")[5]))
df['LC50 [-LOG(mol/L)]'] = df['Chemicals'].apply(lambda x: float(x.split(";")[-1]))
df.drop('Chemicals', axis = 1, inplace = True)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CIC0                908 non-null    float64
#  1   SM1_Dz(Z)           908 non-null    float64
#  2   GATS1i              908 non-null    float64
#  3   NdsCH               908 non-null    float64
#  4   NdssC               908 non-null    float64
#  5   MLOGP               908 non-null    float64
#  6   LC50 [-LOG(mol/L)]  908 non-null    float64
# dtypes: float64(7)
# memory usage: 49.8 KB
#     CIC0  SM1_Dz(Z)  GATS1i  NdsCH  NdssC  MLOGP  LC50 [-LOG(mol/L)]
# 0  2.189      0.580   0.863    0.0    0.0  1.348               3.115
# 1  2.125      0.638   0.831    0.0    0.0  1.348               3.531
# 2  3.027      0.331   1.472    1.0    0.0  1.807               3.510
# 3  2.094      0.827   0.860    0.0    0.0  1.886               5.390
# 4  3.222      0.331   2.177    0.0    0.0  0.706               1.819

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.describe()
# Out:
#              CIC0   SM1_Dz(Z)      GATS1i       NdsCH       NdssC       MLOGP  \
# count  908.000000  908.000000  908.000000  908.000000  908.000000  908.000000
# mean     2.898129    0.628468    1.293591    0.229075    0.485683    2.109285
# std      0.756088    0.428459    0.394303    0.605335    0.861279    1.433181
# min      0.667000    0.000000    0.396000    0.000000    0.000000   -2.884000
# 25%      2.347000    0.223000    0.950750    0.000000    0.000000    1.209000
# 50%      2.934000    0.570000    1.240500    0.000000    0.000000    2.127000
# 75%      3.407000    0.892750    1.562250    0.000000    1.000000    3.105000
# max      5.926000    2.171000    2.920000    4.000000    6.000000    6.515000
#
#        LC50 [-LOG(mol/L)]
# count          908.000000
# mean             4.064431
# std              1.455698
# min              0.053000
# 25%              3.151750
# 50%              3.987500
# 75%              4.907500
# max              9.612000

# %%
sns.distplot(df['LC50 [-LOG(mol/L)]'], hist = True)

# %%
sns.heatmap(df.corr(), annot=True)

# %%
sns.pairplot(df)

# %% [markdown]
# From the simple exploratory graphs above, it is shown that there is no clear linear relationship between the quantity of one particular molecular descriptor and the response variate $LC_{50}$, with the exception of MLOGP, which has a 0.65 correlation with $LC_{50}$.
#
# In the following, Support Vector Machine Regression (SVR) in Scikit learn is used to build a prediction model, with the alternative of an Artificial Neural Network (ANN) from Tensorflow. Finally, the best performing model is adjusted with Principal Component Analysis (PCA) in order to reduce dimension and increase the speed of the algorithm.

# %% [markdown]
# ## Support Vector Regression (SVR)

# %% [markdown]
# First, split the data into a training set and a testing set.

# %%
from sklearn.model_selection import train_test_split
X = df.drop('LC50 [-LOG(mol/L)]', axis = 1)
y = df['LC50 [-LOG(mol/L)]']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# Then, build and fit a SVR model to the training data. First use a linear kernel, with the alternative of the radial basis function kernel.

# %%
from sklearn.svm import SVR
svr = SVR(kernel='linear')
svr.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# Now, use the SVR model to predict, and evaluate its performance.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
predictions = svr.predict(X_test)
print('MAE:', mean_absolute_error(y_test, predictions))
print('MSE:', mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(mean_squared_error(y_test, predictions)))
sns.distplot(y_test - predictions, bins = 50)
# Out:
# MAE: 0.61067591874093
# MSE: 0.6789591017709762
# RMSE: 0.8239897461564532

# %% [markdown]
# In the second attempt, apply a radial basis function kernel to the SVR model, and evaluate its prediction on the testing data.

# %%
svr = SVR(kernel='rbf')
svr.fit(X_train, y_train)
predictions = svr.predict(X_test)

# %%
predDF = pd.DataFrame(y_test.values, columns=['Y Test'])
prediction = pd.Series(predictions.reshape(273,))
predDF = pd.concat([predDF, prediction], axis = 1)
predDF.columns = ['Y Test','Model Predictions']
sns.scatterplot(x='Y Test', y = 'Model Predictions', data = predDF)

# %%
sns.distplot(predDF['Y Test'] - predDF['Model Predictions'], bins = 50)

# %%
print('MAE:', mean_absolute_error(y_test, predictions))
print('MSE:', mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.5970598256116714
# MSE: 0.648675809701318
# RMSE: 0.8054041281874076

# %% [markdown]
# Note that this model is slightly better than the SVR model with linear kernel. Currently, this model is accepted as the best model. However, the RMSE of this model is not ideal (which has approximately 19.8% error). In the following, linear regression will be attempted.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Attempt linear regression on the training data and evaluate its prediction performance on the testing data.

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
plt.scatter(y_test, predictions)
plt.xlabel('y_test')
plt.ylabel('predictions')
# Out:
# Text(0, 0.5, 'predictions')

# %%
print('MAE:', mean_absolute_error(y_test, predictions))
print('MSE:', mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(mean_squared_error(y_test, predictions)))
sns.distplot(y_test - predictions, bins = 50)
# Out:
# MAE: 0.6129943145241861
# MSE: 0.660646467821266
# RMSE: 0.8128016165223012

# %% [markdown]
# Note that this linear regression model is slightly better than SVR with linear kernel, but is slightly worse than SVR with radial basis function kernel, which is currently the best performing model. In the following, an ANN from Tensorflow is attempted to improve model performance.

# %% [markdown]
# ## Artificial Neural Network

# %% [markdown]
# First, data needs to be scaled to standardize the variance.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
X_train.shape, X_test.shape
# Out:
# ((635, 6), (273, 6))

# %% [markdown]
# Next, build various ANN models in the following order:
#  - Rmsprop (gradient descent) optimizer, with Early Stopping mechanism.
#  - Rmsprop (gradient descent) optimizer, with Early Stopping mechanism and Dropout layers.
#  - Adam optimizer, with Early Stopping mechanism.

# %% [markdown]
# First, attempt the Rmsprop optimizer with Early Stopping but without Dropout layers.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()

model.add(Dense(6, activation = 'relu'))
model.add(Dense(6, activation = 'relu'))
model.add(Dense(6, activation = 'relu'))
model.add(Dense(6, activation = 'relu'))

model.add(Dense(1))

model.compile(optimizer = 'rmsprop', loss = 'mse')

# %%
earlyStop = EarlyStopping(monitor='val_loss', mode = 'min', verbose = 1, patience=20)
model.fit(x = X_train, 
          y = y_train.values, 
          validation_data=(X_test, y_test.values),
          batch_size = 64, 
          epochs=500,
          verbose = 1,
          callbacks = [earlyStop])
# Out:
# Train on 635 samples, validate on 273 samples
# Epoch 1/500
# 635/635 [==============================] - 1s 983us/sample - loss: 18.6790 - val_loss: 18.2099
# Epoch 2/500
# 635/635 [==============================] - 0s 29us/sample - loss: 18.0952 - val_loss: 17.7551
# Epoch 3/500
# 635/635 [==============================] - 0s 27us/sample - loss: 17.6418 - val_loss: 17.2726
# Epoch 4/500
# 635/635 [==============================] - 0s 29us/sample - loss: 17.1434 - val_loss: 16.7239
# Epoch 5/500
# 635/635 [==============================] - 0s 29us/sample - loss: 16.5873 - val_loss: 16.1203
# Epoch 6/500
# 635/635 [==============================] - 0s 30us/sample - loss: 15.9647 - val_loss: 15.4439
# Epoch 7/500
# 635/635 [==============================] - 0s 31us/sample - loss: 15.2831 - val_loss: 14.7106
500
# 635/635 [==============================] - 0s 29us/sample - loss: 0.9240 - val_loss: 0.6475
# Epoch 00164: early stopping

# %% [markdown]
# Monitor the training process and evaluate the model performance.

# %%
modelLoss = pd.DataFrame(model.history.history)
modelLoss.plot()

# %%
trainScore = model.evaluate(X_train, y_train, verbose = 0)
testScore = model.evaluate(X_test, y_test, verbose = 0)
trainScore, testScore
# Out:
# (0.9186066175070334, 0.6474737444203416)

# %% [markdown]
# Notice that the scores have approximately 0.3 difference, which is considerable for a response variate with a mean of approximately 4.
#
# Further evaluate the model prediction performance.

# %%
prediction = model.predict(X_test)
predDF = pd.DataFrame(y_test.values, columns=['Y Test'])
prediction = pd.Series(prediction.reshape(273,))
predDF = pd.concat([predDF, prediction], axis = 1)
predDF.columns = ['Y Test','Model Predictions']
sns.scatterplot(x='Y Test', y = 'Model Predictions', data = predDF)

# %%
sns.distplot(predDF['Y Test'] - predDF['Model Predictions'], bins = 50)

# %%
# MAE, MSE, RMSE
print(mean_absolute_error(predDF['Y Test'],predDF['Model Predictions']))
print(mean_squared_error(predDF['Y Test'],predDF['Model Predictions']))
print(np.sqrt(mean_squared_error(predDF['Y Test'],predDF['Model Predictions'])))
# Out:
# 0.6022623935950983
# 0.6474737390857223
# 0.8046575290679397

# %% [markdown]
# Note that the errors are greater than that of the current best model. In the following, Dropout layers are added in attempt to improve the model.

# %%
model = Sequential()

model.add(Dense(6, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(6, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(6, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(6, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(1))

model.compile(optimizer = 'rmsprop', loss = 'mse')

# %%
earlyStop = EarlyStopping(monitor='val_loss', mode = 'min', verbose = 1, patience=20)
model.fit(x = X_train, 
          y = y_train.values, 
          validation_data=(X_test, y_test.values),
          batch_size = 64, 
          epochs=500,
          verbose = 1,
          callbacks = [earlyStop])
# Out:
# Train on 635 samples, validate on 273 samples
# Epoch 1/500
# 635/635 [==============================] - 0s 741us/sample - loss: 18.4496 - val_loss: 18.1627
# Epoch 2/500
# 635/635 [==============================] - 0s 29us/sample - loss: 18.0779 - val_loss: 17.8081
# Epoch 3/500
# 635/635 [==============================] - 0s 30us/sample - loss: 17.6920 - val_loss: 17.3993
# Epoch 4/500
# 635/635 [==============================] - 0s 31us/sample - loss: 17.2452 - val_loss: 16.9203
# Epoch 5/500
# 635/635 [==============================] - 0s 32us/sample - loss: 16.7683 - val_loss: 16.3862
# Epoch 6/500
# 635/635 [==============================] - 0s 32us/sample - loss: 16.2375 - val_loss: 15.7747
# Epoch 7/500
# 635/635 [==============================] - 0s 28us/sample - loss: 15.5964 - val_loss: 15.0458
# Epoch 8/500
# 635/635 [==============================] - 0s 30us/sample - loss: 14.9756 - val_loss: 14.2150
# Epoch 9/500
# 635/635 [==============================] - 0s 30us/sample - loss: 14.1200 - val_loss: 13.2791
# Epoch 10/500
# 635/635 [==============================] - 0s 27us/sample - loss: 13.2919 - val_loss: 12.2742
# Epoch 11/500
# 635/635 [==============================] - 0s 30us/sample - loss: 12.2989 - val_loss: 11.1861
# Epoch 12/500
500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.6952 - val_loss: 1.2148
# Epoch 89/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.8170 - val_loss: 1.1704
# Epoch 90/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.6731 - val_loss: 1.1941
# Epoch 91/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.7093 - val_loss: 1.1761
# Epoch 92/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.8274 - val_loss: 1.1865
# Epoch 93/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.8368 - val_loss: 1.1586
# Epoch 94/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.8205 - val_loss: 1.1828
# Epoch 95/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.7553 - val_loss: 1.1378
# Epoch 96/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.7757 - val_loss: 1.2008
# Epoch 97/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.6374 - val_loss: 1.0842
# Epoch 98/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.8865 - val_loss: 1.1356
# Epoch 99/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.6549 - val_loss: 1.1655
# Epoch 100/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.3397 - val_loss: 1.1573
# Epoch 101/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.6868 - val_loss: 1.1266
# Epoch 102/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.6838 - val_loss: 1.1553
# Epoch 103/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.6540 - val_loss: 1.1175
# Epoch 104/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.4138 - val_loss: 1.1223
# Epoch 105/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.5856 - val_loss: 1.1285
# Epoch 106/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.4979 - val_loss: 1.1046
# Epoch 107/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.5379 - val_loss: 1.1270
# Epoch 108/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.6320 - val_loss: 1.0674
# Epoch 109/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.4757 - val_loss: 1.1869
# Epoch 110/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.3589 - val_loss: 1.0607
# Epoch 111/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.6658 - val_loss: 1.0955
# Epoch 112/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.6109 - val_loss: 1.0913
# Epoch 113/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.4272 - val_loss: 1.0326
# Epoch 114/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.3700 - val_loss: 1.0696
# Epoch 115/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.3057 - val_loss: 1.0669
# Epoch 116/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.4621 - val_loss: 0.9868
# Epoch 117/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.4401 - val_loss: 1.0783
# Epoch 118/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.2901 - val_loss: 1.0753
# Epoch 119/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.2423 - val_loss: 1.0611
# Epoch 120/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.4133 - val_loss: 1.0491
# Epoch 121/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.4874 - val_loss: 1.1268
# Epoch 122/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.3521 - val_loss: 1.0624
# Epoch 123/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.1443 - val_loss: 1.0349
# Epoch 124/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.2654 - val_loss: 1.0369
# Epoch 125/500
# 635/635 [==============================] - 0s 26us/sample - loss: 2.3208 - val_loss: 0.9824
# Epoch 126/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.2911 - val_loss: 1.0336
# Epoch 127/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.3135 - val_loss: 1.0297
# Epoch 128/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.1398 - val_loss: 0.9445
# Epoch 129/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.0684 - val_loss: 0.9823
# Epoch 130/500
# 635/635 [==============================] - 0s 30us/sample - loss: 2.0290 - val_loss: 0.9928
# Epoch 131/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.1997 - val_loss: 0.9702
# Epoch 132/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.2038 - val_loss: 0.9596
# Epoch 133/500
# 635/635 [==============================] - 0s 30us/sample - loss: 2.1311 - val_loss: 0.9310
# Epoch 134/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.1370 - val_loss: 0.9788
# Epoch 135/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.2789 - val_loss: 0.9914
# Epoch 136/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0903 - val_loss: 0.9785
# Epoch 137/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.2719 - val_loss: 1.0029
# Epoch 138/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.1090 - val_loss: 0.9599
# Epoch 139/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.3033 - val_loss: 0.9525
# Epoch 140/500
# 635/635 [==============================] - 0s 27us/sample - loss: 1.9998 - val_loss: 0.9481
# Epoch 141/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.1687 - val_loss: 0.9511
# Epoch 142/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.1449 - val_loss: 0.9464
# Epoch 143/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.2289 - val_loss: 0.9394
# Epoch 144/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.2315 - val_loss: 0.9646
# Epoch 145/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0219 - val_loss: 0.9118
# Epoch 146/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.2899 - val_loss: 0.9441
# Epoch 147/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0628 - val_loss: 0.9373
# Epoch 148/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0234 - val_loss: 0.9388
# Epoch 149/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.9790 - val_loss: 0.9857
# Epoch 150/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.3311 - val_loss: 0.9847
# Epoch 151/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.1783 - val_loss: 0.9386
# Epoch 152/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.0291 - val_loss: 0.9368
# Epoch 153/500
# 635/635 [==============================] - 0s 27us/sample - loss: 1.9979 - val_loss: 0.9733
# Epoch 154/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.8828 - val_loss: 0.9290
# Epoch 155/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0407 - val_loss: 0.8982
# Epoch 156/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.1239 - val_loss: 0.9778
# Epoch 157/500
# 635/635 [==============================] - 0s 29us/sample - loss: 2.0300 - val_loss: 0.9457
# Epoch 158/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0180 - val_loss: 0.9400
# Epoch 159/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0623 - val_loss: 0.9012
# Epoch 160/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.9556 - val_loss: 0.9072
# Epoch 161/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.0235 - val_loss: 0.9310
# Epoch 162/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.0255 - val_loss: 0.8924
# Epoch 163/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.0253 - val_loss: 0.9652
# Epoch 164/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.9713 - val_loss: 0.8661
# Epoch 165/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.9803 - val_loss: 0.8917
# Epoch 166/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.9822 - val_loss: 0.9504
# Epoch 167/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.9834 - val_loss: 0.9039
# Epoch 168/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.9653 - val_loss: 0.9310
# Epoch 169/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.8806 - val_loss: 0.9079
# Epoch 170/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.9128 - val_loss: 0.9066
# Epoch 171/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0373 - val_loss: 0.9082
# Epoch 172/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.8610 - val_loss: 0.9336
# Epoch 173/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.8719 - val_loss: 0.9207
# Epoch 174/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.8961 - val_loss: 0.9304
# Epoch 175/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.9585 - val_loss: 0.8974
# Epoch 176/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.8969 - val_loss: 0.8981
# Epoch 177/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0662 - val_loss: 0.9035
# Epoch 178/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.7525 - val_loss: 0.8748
# Epoch 179/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.9720 - val_loss: 0.9074
# Epoch 180/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.1955 - val_loss: 0.8992
# Epoch 181/500
# 635/635 [==============================] - 0s 28us/sample - loss: 2.0354 - val_loss: 0.9353
# Epoch 182/500
# 635/635 [==============================] - 0s 27us/sample - loss: 1.9288 - val_loss: 0.8839
# Epoch 183/500
# 635/635 [==============================] - 0s 27us/sample - loss: 1.8540 - val_loss: 0.9161
# Epoch 184/500
# 635/635 [==============================] - 0s 27us/sample - loss: 2.0407 - val_loss: 0.9598
# Epoch 00184: early stopping

# %% [markdown]
# Monitor the training process and evaluate the model performance.

# %%
modelLoss = pd.DataFrame(model.history.history)
modelLoss.plot()

# %%
prediction = model.predict(X_test)
predDF = pd.DataFrame(y_test.values, columns=['Y Test'])
prediction = pd.Series(prediction.reshape(273,))
predDF = pd.concat([predDF, prediction], axis = 1)
predDF.columns = ['Y Test','Model Predictions']
sns.scatterplot(x='Y Test', y = 'Model Predictions', data = predDF)

# %%
sns.distplot(predDF['Y Test'] - predDF['Model Predictions'], bins = 50)

# %%
# MAE, MSE, RMSE
print(mean_absolute_error(predDF['Y Test'],predDF['Model Predictions']))
print(mean_squared_error(predDF['Y Test'],predDF['Model Predictions']))
print(np.sqrt(mean_squared_error(predDF['Y Test'],predDF['Model Predictions'])))
# Out:
# 0.7435311851990529
# 0.9598180468919105
# 0.9797030401565112

# %% [markdown]
# Note that the error for the model with Dropout layers are much higher than that of the previous models. Thus, an ANN with adam optimizer but without the dropout layers is attempted.

# %%
model = Sequential()

model.add(Dense(6, activation = 'relu'))

model.add(Dense(6, activation = 'relu'))

model.add(Dense(6, activation = 'relu'))

model.add(Dense(6, activation = 'relu'))

model.add(Dense(1))

model.compile(optimizer = 'adam', loss = 'mse')

# %%
earlyStop = EarlyStopping(monitor='val_loss', mode = 'min', verbose = 1, patience=20)
model.fit(x = X_train, 
          y = y_train.values, 
          validation_data=(X_test, y_test.values),
          batch_size = 64, 
          epochs=500,
          verbose = 1,
          callbacks = [earlyStop])
# Out:
# Train on 635 samples, validate on 273 samples
# Epoch 1/500
# 635/635 [==============================] - 0s 450us/sample - loss: 18.6561 - val_loss: 18.4357
# Epoch 2/500
# 635/635 [==============================] - 0s 24us/sample - loss: 18.4161 - val_loss: 18.1977
# Epoch 3/500
# 635/635 [==============================] - 0s 26us/sample - loss: 18.1680 - val_loss: 17.9268
# Epoch 4/500
# 635/635 [==============================] - 0s 29us/sample - loss: 17.8789 - val_loss: 17.6013
# Epoch 5/500
# 635/635 [==============================] - 0s 29us/sample - loss: 17.5265 - val_loss: 17.2078
# Epoch 6/500
# 635/635 [==============================] - 0s 30us/sample - loss: 17.0997 - val_loss: 16.7301
# Epoch 7/500
# 635/635 [==============================] - 0s 30us/sample - loss: 16.5840 - val_loss: 16.1500
# Epoch 8/500
# 635/635 [==============================] - 0s 31us/sample - loss: 15.9489 - val_loss: 15.4462
# Epoch 9/500
# 635/635 [==============================] - 0s 30us/sample - loss: 15.1849 - val_loss: 14.5683
# Epoch 10/500
# 635/635 [==============================] - 0s 27us/sample - loss: 14.2145 - val_loss: 13.4860
# Epoch 11/500
# 635/635 [==============================] - 0s 28us/sample - loss: 13.0267 - val_loss: 12.1599
# Epoch 12/500
# 635/635 [==============================] - 0s 27us/sample - loss: 11.6185 - val_loss: 10.5672
# Epoch 13/500
# 635/635 [==============================] - 0s 28us/sample - loss: 9.9523 - val_loss: 8.7842
# Epoch 14/500
# 635/635 [==============================] - 0s 29us/sample - loss: 8.1410 - val_loss: 6.9040
# Epoch 15/500
# 635/635 [==============================] - 0s 30us/sample - loss: 6.2863 - val_loss: 5.0926
# Epoch 16/500
# 635/635 [==============================] - 0s 31us/sample - loss: 4.6107 - val_loss: 3.4686
# Epoch 17/500
# 635/635 [==============================] - 0s 30us/sample - loss: 3.1808 - val_loss: 2.3026
# Epoch 18/500
# 635/635 [==============================] - 0s 30us/sample - loss: 2.2950 - val_loss: 1.6797
# Epoch 19/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.9222 - val_loss: 1.4714
# Epoch 20/500
# 635/635 [==============================] - 0s 32us/sample - loss: 1.8471 - val_loss: 1.4598
# Epoch 21/500
# 635/635 [==============================] - 0s 33us/sample - loss: 1.8512 - val_loss: 1.4465
# Epoch 22/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.8330 - val_loss: 1.4334
# Epoch 23/500
# 635/635 [==============================] - 0s 32us/sample - loss: 1.8172 - val_loss: 1.4242
# Epoch 24/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.8055 - val_loss: 1.4122
# Epoch 25/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.7920 - val_loss: 1.4004
# Epoch 26/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.7764 - val_loss: 1.3852
# Epoch 27/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.7618 - val_loss: 1.3718
# Epoch 28/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.7491 - val_loss: 1.3601
# Epoch 29/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.7389 - val_loss: 1.3463
# Epoch 30/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.7201 - val_loss: 1.3348
# Epoch 31/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.7087 - val_loss: 1.3243
# Epoch 32/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.6945 - val_loss: 1.3092
# Epoch 33/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.6796 - val_loss: 1.2955
# Epoch 34/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.6673 - val_loss: 1.2825
# Epoch 35/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.6516 - val_loss: 1.2694
# Epoch 36/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.6365 - val_loss: 1.2568
# Epoch 37/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.6230 - val_loss: 1.2441
# Epoch 38/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.6076 - val_loss: 1.2291
# Epoch 39/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.5939 - val_loss: 1.2147
# Epoch 40/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.5782 - val_loss: 1.2006
# Epoch 41/500
# 635/635 [==============================] - 0s 27us/sample - loss: 1.5645 - val_loss: 1.1869
# Epoch 42/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.5480 - val_loss: 1.1715
# Epoch 43/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.5329 - val_loss: 1.1567
# Epoch 44/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.5157 - val_loss: 1.1418
# Epoch 45/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.5014 - val_loss: 1.1269
# Epoch 46/500
# 635/635 [==============================] - 0s 27us/sample - loss: 1.4837 - val_loss: 1.1113
# Epoch 47/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.4676 - val_loss: 1.0956
# Epoch 48/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.4516 - val_loss: 1.0806
# Epoch 49/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.4347 - val_loss: 1.0646
# Epoch 50/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.4167 - val_loss: 1.0486
# Epoch 51/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.3996 - val_loss: 1.0323
# Epoch 52/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.3831 - val_loss: 1.0152
# Epoch 53/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.3661 - val_loss: 0.9994
# Epoch 54/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.3497 - val_loss: 0.9841
# Epoch 55/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.3320 - val_loss: 0.9676
# Epoch 56/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.3187 - val_loss: 0.9536
# Epoch 57/500
# 635/635 [==============================] - 0s 26us/sample - loss: 1.2986 - val_loss: 0.9348
# Epoch 58/500
# 635/635 [==============================] - 0s 25us/sample - loss: 1.2854 - val_loss: 0.9203
# Epoch 59/500
# 635/635 [==============================] - 0s 25us/sample - loss: 1.2664 - val_loss: 0.9038
# Epoch 60/500
# 635/635 [==============================] - 0s 26us/sample - loss: 1.2506 - val_loss: 0.8912
# Epoch 61/500
# 635/635 [==============================] - 0s 27us/sample - loss: 1.2372 - val_loss: 0.8743
# Epoch 62/500
# 635/635 [==============================] - 0s 28us/sample - loss: 1.2283 - val_loss: 0.8629
# Epoch 63/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.2088 - val_loss: 0.8473
# Epoch 64/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.1998 - val_loss: 0.8333
# Epoch 65/500
# 635/635 [==============================] - 0s 33us/sample - loss: 1.1798 - val_loss: 0.8269
# Epoch 66/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.1702 - val_loss: 0.8129
# Epoch 67/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.1575 - val_loss: 0.7980
# Epoch 68/500
# 635/635 [==============================] - 0s 32us/sample - loss: 1.1479 - val_loss: 0.7897
# Epoch 69/500
# 635/635 [==============================] - 0s 33us/sample - loss: 1.1350 - val_loss: 0.7778
# Epoch 70/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.1265 - val_loss: 0.7718
# Epoch 71/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.1175 - val_loss: 0.7583
# Epoch 72/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.1090 - val_loss: 0.7542
# Epoch 73/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.0999 - val_loss: 0.7420
# Epoch 74/500
# 635/635 [==============================] - 0s 29us/sample - loss: 1.0937 - val_loss: 0.7345
# Epoch 75/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.0845 - val_loss: 0.7287
# Epoch 76/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.0796 - val_loss: 0.7216
# Epoch 77/500
# 635/635 [==============================] - 0s 27us/sample - loss: 1.0714 - val_loss: 0.7166
# Epoch 78/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.0678 - val_loss: 0.7108
# Epoch 79/500
# 635/635 [==============================] - 0s 32us/sample - loss: 1.0609 - val_loss: 0.7032
# Epoch 80/500
# 635/635 [==============================] - 0s 32us/sample - loss: 1.0642 - val_loss: 0.7042
# Epoch 81/500
# 635/635 [==============================] - 0s 32us/sample - loss: 1.0498 - val_loss: 0.6897
# Epoch 82/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.0478 - val_loss: 0.6903
# Epoch 83/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.0426 - val_loss: 0.6897
# Epoch 84/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.0413 - val_loss: 0.6858
# Epoch 85/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.0420 - val_loss: 0.6778
# Epoch 86/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.0322 - val_loss: 0.6790
# Epoch 87/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.0293 - val_loss: 0.6740
# Epoch 88/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.0269 - val_loss: 0.6687
# Epoch 89/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.0257 - val_loss: 0.6695
# Epoch 90/500
# 635/635 [==============================] - 0s 31us/sample - loss: 1.0299 - val_loss: 0.6612
# Epoch 91/500
# 635/635 [==============================] - 0s 30us/sample - loss: 1.
500
# 635/635 [==============================] - 0s 26us/sample - loss: 0.9840 - val_loss: 0.6387
# Epoch 135/500
# 635/635 [==============================] - 0s 25us/sample - loss: 0.9858 - val_loss: 0.6468
# Epoch 136/500
# 635/635 [==============================] - 0s 27us/sample - loss: 0.9924 - val_loss: 0.6344
# Epoch 137/500
# 635/635 [==============================] - 0s 27us/sample - loss: 0.9870 - val_loss: 0.6676
# Epoch 138/500
# 635/635 [==============================] - 0s 29us/sample - loss: 0.9897 - val_loss: 0.6348
# Epoch 139/500
# 635/635 [==============================] - 0s 29us/sample - loss: 0.9829 - val_loss: 0.6406
# Epoch 140/500
# 635/635 [==============================] - 0s 29us/sample - loss: 0.9882 - val_loss: 0.6553
# Epoch 141/500
# 635/635 [==============================] - 0s 28us/sample - loss: 0.9912 - val_loss: 0.6336
# Epoch 142/500
# 635/635 [==============================] - 0s 29us/sample - loss: 0.9850 - val_loss: 0.6615
# Epoch 143/500
# 635/635 [==============================] - 0s 28us/sample - loss: 0.9846 - val_loss: 0.6391
# Epoch 144/500
# 635/635 [==============================] - 0s 31us/sample - loss: 0.9840 - val_loss: 0.6436
# Epoch 145/500
# 635/635 [==============================] - 0s 30us/sample - loss: 0.9812 - val_loss: 0.6386
# Epoch 146/500
# 635/635 [==============================] - 0s 29us/sample - loss: 0.9793 - val_loss: 0.6439
# Epoch 147/500
# 635/635 [==============================] - 0s 29us/sample - loss: 0.9789 - val_loss: 0.6459
# Epoch 148/500
# 635/635 [==============================] - 0s 30us/sample - loss: 0.9827 - val_loss: 0.6437
# Epoch 149/500
# 635/635 [==============================] - 0s 28us/sample - loss: 0.9820 - val_loss: 0.6496
# Epoch 150/500
# 635/635 [==============================] - 0s 28us/sample - loss: 0.9771 - val_loss: 0.6385
# Epoch 151/500
# 635/635 [==============================] - 0s 30us/sample - loss: 0.9820 - val_loss: 0.6380
# Epoch 152/500
# 635/635 [==============================] - 0s 28us/sample - loss: 0.9773 - val_loss: 0.6566
# Epoch 153/500
# 635/635 [==============================] - 0s 30us/sample - loss: 0.9788 - val_loss: 0.6446
# Epoch 154/500
# 635/635 [==============================] - 0s 28us/sample - loss: 0.9784 - val_loss: 0.6447
# Epoch 155/500
# 635/635 [==============================] - 0s 28us/sample - loss: 0.9817 - val_loss: 0.6367
# Epoch 156/500
# 635/635 [==============================] - 0s 32us/sample - loss: 0.9791 - val_loss: 0.6484
# Epoch 157/500
# 635/635 [==============================] - 0s 31us/sample - loss: 0.9798 - val_loss: 0.6471
# Epoch 158/500
# 635/635 [==============================] - 0s 29us/sample - loss: 0.9798 - val_loss: 0.6353
# Epoch 159/500
# 635/635 [==============================] - 0s 28us/sample - loss: 0.9797 - val_loss: 0.6574
# Epoch 160/500
# 635/635 [==============================] - 0s 27us/sample - loss: 0.9831 - val_loss: 0.6361
# Epoch 161/500
# 635/635 [==============================] - 0s 26us/sample - loss: 0.9804 - val_loss: 0.6514
# Epoch 00161: early stopping

# %% [markdown]
# Monitor the training process and evaluate the model performance.

# %%
modelLoss = pd.DataFrame(model.history.history)
modelLoss.plot()

# %%
trainScore = model.evaluate(X_train, y_train, verbose = 0)
testScore = model.evaluate(X_test, y_test, verbose = 0)
trainScore, testScore
# Out:
# (0.9760275619236503, 0.6514134778207912)

# %%
prediction = model.predict(X_test)
predDF = pd.DataFrame(y_test.values, columns=['Y Test'])
prediction = pd.Series(prediction.reshape(273,))
predDF = pd.concat([predDF, prediction], axis = 1)
predDF.columns = ['Y Test','Model Predictions']
sns.scatterplot(x='Y Test', y = 'Model Predictions', data = predDF)

# %%
sns.distplot(predDF['Y Test'] - predDF['Model Predictions'], bins = 100)

# %%
# MAE, MSE, RMSE
print(mean_absolute_error(predDF['Y Test'],predDF['Model Predictions']))
print(mean_squared_error(predDF['Y Test'],predDF['Model Predictions']))
print(np.sqrt(mean_squared_error(predDF['Y Test'],predDF['Model Predictions'])))
# Out:
# 0.6151891960521321
# 0.6514135038024089
# 0.8071019166142581

# %% [markdown]
# Note that this is still worse than the current best model, the SVR model with a radial basis function kernel, which would now be accepted as the best model for this dataset.

# %% [markdown]
# ##  Support Vector Regression Revisited
#
# The support vector regression model is experimented to have the best performance. In the following, Principal Component Analysis (PCA) will be attempted to improve the model. First, observe the current best model:

# %%
X = df.drop('LC50 [-LOG(mol/L)]', axis = 1)
y = df['LC50 [-LOG(mol/L)]']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
svr = SVR(kernel='rbf')
svr.fit(X_train, y_train)
predictions = svr.predict(X_test)

# %%
print('MAE:', mean_absolute_error(y_test, predictions))
print('MSE:', mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.5970598256116714
# MSE: 0.648675809701318
# RMSE: 0.8054041281874076

# %% [markdown]
# Attempting to use PCA to reduce dimension and speed up the algorithm gives:

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df.drop('LC50 [-LOG(mol/L)]', axis =1))
scaled_data = scaler.transform(df.drop('LC50 [-LOG(mol/L)]', axis =1))

# %% [markdown]
# Split the data, then train the PCA model on the training data only. Finally, apply the PCA model on both the training data and the testing data to reduce their dimensions.

# %%
X = df.drop('LC50 [-LOG(mol/L)]', axis = 1)
y = df['LC50 [-LOG(mol/L)]']
X_train, X_test, y_train, y_test = train_test_split(scaled_data, 
                                                    y, 
                                                    test_size=0.30, 
                                                    random_state=101)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X_train)
xTrainPCA = pca.transform(X_train)
xTestPCA = pca.transform(X_test)

# %% [markdown]
# The relatinoship between the PCA indicator and the six molecular descriptors are shown below:

# %%
df_comp = pd.DataFrame(pca.components_, columns=df.drop('LC50 [-LOG(mol/L)]', axis =1).columns)
plt.figure(figsize = (12, 6))
sns.heatmap(df_comp, cmap='plasma')

# %% [markdown]
# In this way, the PCA indicators, instead of the six molecular descriptors, can be used to train the SVR model with radial basis function kernel.

# %%
svrPCA = SVR(kernel='rbf')
svrPCA.fit(xTrainPCA, y_train)
predictions = svrPCA.predict(xTestPCA)

# %%
print('MAE:', mean_absolute_error(y_test, predictions))
print('MSE:', mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.6387268135017251
# MSE: 0.7432998993485277
# RMSE: 0.8621484207191519

# %% [markdown]
# Observe that the PCA indicators are not good at predicting the response variate comparing to the original six molecular descriptors. This confirms that the SVR model with radial basis function kernel, using the molecular descriptors provided, performs the best.
#
# In the following, this model is used to predict a single entry.

# %%
entry = df['LC50 [-LOG(mol/L)]'].iloc[904]
pred = svr.predict([df.drop('LC50 [-LOG(mol/L)]', axis = 1).iloc[904].values.reshape(6, )])
print("The model-predicted toxin level is: ",  pred[0])
print("The actual toxin level is: " , entry)
# Out:
# The model-predicted toxin level is:  4.918001405697297
# The actual toxin level is:  4.818

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The research conducted by M. Cassotti et al. provides six molecular descriptors that have a certain degree of correlations with the response variate $LC_{50}$. In the experimental process described above, it is shown after evaluating the performance of various models including SVR with linear kernel and RBF kernel, linear regression, as well as ANN with Rmsprop and Adam optimizers, that the SVR model with radial basis function kernel, using the molecular descriptors provided, performs the best. The model has a Root Mean Squared Error (RMSE) of 0.805, which is an approximately 19.8% error of the response variate $LC_{50}$. While this error is considerable to some extent, it is shown with sufficient evidence that the six molecular descriptors are correlated to $LC_{50}$  and can be used to predict the toxin level in fathead minnow.

# %%
from joblib import dump
dump(svr, 'FatheadMinnowModel.h5')
# Out:
# ['FatheadMinnowModel.h5']
